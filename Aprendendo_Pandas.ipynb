# %% [markdown]
# <a href="https://colab.research.google.com/github/thaisgulias/DataAnalytics_student/blob/main/Aprendendo_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Instalação de bibliotecas

# %%
pip install gcsfs
# Out:
# Installing collected packages: fsspec, gcsfs
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.1.0
#     Uninstalling fsspec-2023.1.0:
#       Successfully uninstalled fsspec-2023.1.0
# Successfully installed fsspec-2023.3.0 gcsfs-2023.3.0

# %%
pip install pandera

# %% [markdown]
# ##Declaração das LIBS

# %%
import pandas as pd
import os
import numpy as np
from google.cloud import storage
import pandera as pa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-602dca5ec77c> in <module>
#       3 import numpy as np
#       4 from google.cloud import storage
# ----> 5 import pandera as pa
#
# ModuleNotFoundError: No module named 'pandera'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ##Config . do pandas

# %%
pd.set_option('display.max_columns',100)

# %% [markdown]
# ##Conector para Cloud Storage(bucket)

# %%
#CONFIGURANDO DA CHAVE DE SEGURANCA (Enviada com o projeto)

# serviceAccount = '/content/compact-epigram-377819-c2c380ae78c0.json'
# os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# %%
# Configurações Google Cloud Storage
# client = storage.Client()
# bucket = client.get_bucket('projeto_pandas')
# bucket.blob('teste.csv')
# path = 'gs://projeto_pandas/brutos/teste.csv'

# %% [markdown]
# ##Extração dos dados(Extract)

# %%
df = pd.read_csv(path,sep=';',encoding='ISO-8859-1',parse_dates=['ocorrencia_dia'],dayfirst=True)

# %% [markdown]
# ##Pré analise

# %%
#Visualização do arquivo(dados)
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 81027               81027               81027
# 1                 81030               81030               81030
# 2                 81023               81023               81023
# 3                 81029               81029               81029
# 4                 81025               81025               81025
# ...                 ...                 ...                 ...
# 6764              40324               40324               40324
# 6765              39527               39527               39527
# 6766              40211               40211               40211
# 6767              40349               40349               40349
# 6768              40351               40351               40351
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  81027               81027          INCIDENTE GRAVE
# 1                  81030               81030                INCIDENTE
# 2                  81023               81023          INCIDENTE GRAVE
# 3                  81029               81029                INCIDENTE
# 4                  81025               81025                INCIDENTE
# ...                  ...                 ...                      ...
# 6764               40324               40324                INCIDENTE
# 6765               39527               39527                 ACIDENTE
# 6766               40211               40211                INCIDENTE
# 6767               40349               40349                INCIDENTE
# 6768               40351               40351                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    NaN                  NaN           SÃO PAULO
# 1                    NaN                  NaN             VITÓRIA
# 2                    NaN                  NaN           AMERICANA
# 3                    NaN                  NaN      BELO HORIZONTE
# 4                    NaN                  NaN              MANAUS
# ...                  ...                  ...                 ...
# 6764                 NaN                  NaN             PELOTAS
# 6765      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 6766                 ***                  ***      RIO DE JANEIRO
# 6767                 NaN                  NaN               BELÉM
# 6768                 NaN                  NaN      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia  \
# 0               SP          BRASIL                 SBSP     2022-10-09
# 1               ES          BRASIL                 SBVT     2022-10-09
# 2               SP          BRASIL                 SDAI     2022-10-06
# 3               MG          BRASIL                 SBBH     2022-10-06
# 4               AM          BRASIL                 SBEG     2022-10-05
# ...            ...             ...                  ...            ...
# 6764            RS          BRASIL                 SBPK     2010-01-05
# 6765            MT          BRASIL                  ***     2010-01-04
# 6766            RJ          BRASIL                  ***     2010-01-03
# 6767            PA          BRASIL                 SBBE     2010-01-03
# 6768            RJ          BRASIL                 SBRJ     2010-01-03
#
#      ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0           16:30:00                            SIM               ATIVA
# 1           16:20:00                            SIM               ATIVA
# 2           15:30:00                            SIM          FINALIZADA
# 3           00:44:00                            SIM          FINALIZADA
# 4           20:56:00                            SIM          FINALIZADA
# ...              ...                            ...                 ...
# 6764        19:25:00                            SIM          FINALIZADA
# 6765        17:30:00                            SIM          FINALIZADA
# 6766        12:00:00                            SIM          FINALIZADA
# 6767        11:05:00                            SIM          FINALIZADA
# 6768        03:00:00                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                      A DEFINIR                            NÃO
# 1                      A DEFINIR                            NÃO
# 2                            ***                            NÃO
# 3                            ***                            NÃO
# 4                            ***                            NÃO
# ...                          ...                            ...
# 6764                         NaN                            NÃO
# 6765           A-539/CENIPA/2018                            SIM
# 6766                         ***                            NÃO
# 6767                         NaN                            NÃO
# 6768                         NaN                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 0                          NaN                    0
# 1                          NaN                    0
# 2                          NaN                    0
# 3                          NaN                    0
# 4                          NaN                    0
# ...                        ...                  ...
# 6764                       NaN                    0
# 6765                2019-10-28                    0
# 6766                       NaN                    0
# 6767                       NaN                    0
# 6768                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 0                              1                    SIM
# 1                              1                    NÃO
# 2                              1                    SIM
# 3                              1                    NÃO
# 4                              1                    NÃO
# ...                          ...                    ...
# 6764                           1                    NÃO
# 6765                           1                    NÃO
# 6766                           1                    NÃO
# 6767                           1                    NÃO
# 6768                           1                    NÃO
#
# [6769 rows x 22 columns]

# %%
#Vis . do df começando pelo cabeçalho
df.head(3)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              81027               81027               81027
# 1              81030               81030               81030
# 2              81023               81023               81023
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               81027               81027          INCIDENTE GRAVE
# 1               81030               81030                INCIDENTE
# 2               81023               81023          INCIDENTE GRAVE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN         SÃO PAULO            SP
# 1                 NaN                  NaN           VITÓRIA            ES
# 2                 NaN                  NaN         AMERICANA            SP
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 SBSP     2022-10-09        16:30:00
# 1          BRASIL                 SBVT     2022-10-09        16:20:00
# 2          BRASIL                 SDAI     2022-10-06        15:30:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM               ATIVA
# 1                            SIM               ATIVA
# 2                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                   A DEFINIR                            NÃO
# 1                   A DEFINIR                            NÃO
# 2                         ***                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
# 1                       NaN                    0                           1
# 2                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    SIM
# 1                    NÃO
# 2                    SIM

# %%
#Vis . do df começando pelo final 
df.tail(1)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 6768              40351               40351               40351
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 6768               40351               40351                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 6768                 NaN                  NaN    RIO DE JANEIRO            RJ
#
#      ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 6768          BRASIL                 SBRJ     03/01/2010        03:00:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 6768                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 6768                         NaN                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 6768                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 6768                           1                    NÃO

# %%
#Tipo de dados das colunas
df.dtypes
# Out:
# codigo_ocorrencia                  int64
# codigo_ocorrencia1                 int64
# codigo_ocorrencia2                 int64
# codigo_ocorrencia3                 int64
# codigo_ocorrencia4                 int64
# ocorrencia_classificacao          object
# ocorrencia_latitude               object
# ocorrencia_longitude              object
# ocorrencia_cidade                 object
# ocorrencia_uf                     object
# ocorrencia_pais                   object
# ocorrencia_aerodromo              object
# ocorrencia_dia                    object
# ocorrencia_hora                   object
# investigacao_aeronave_liberada    object
# investigacao_status               object
# divulgacao_relatorio_numero       object
# divulgacao_relatorio_publicado    object
# divulgacao_dia_publicacao         object
# total_recomendacoes                int64
# total_aeronaves_envolvidas         int64
# ocorrencia_saida_pista            object
# dtype: object

# %%
#Tam. do DF
df.shape
# Out:
# (6769, 22)

# %%
#Info detalhada do DF
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6769 entries, 0 to 6768
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   codigo_ocorrencia               6769 non-null   int64
#  1   codigo_ocorrencia1              6769 non-null   int64
#  2   codigo_ocorrencia2              6769 non-null   int64
#  3   codigo_ocorrencia3              6769 non-null   int64
#  4   codigo_ocorrencia4              6769 non-null   int64
#  5   ocorrencia_classificacao        6769 non-null   object
#  6   ocorrencia_latitude             5135 non-null   object
#  7   ocorrencia_longitude            5135 non-null   object
#  8   ocorrencia_cidade               6769 non-null   object
#  9   ocorrencia_uf                   6769 non-null   object
#  10  ocorrencia_pais                 6769 non-null   object
#  11  ocorrencia_aerodromo            6769 non-null   object
#  12  ocorrencia_dia                  6769 non-null   datetime64[ns]
#  13  ocorrencia_hora                 6767 non-null   object
#  14  investigacao_aeronave_liberada  6531 non-null   object
#  15  investigacao_status             6428 non-null   object
#  16  divulgacao_relatorio_numero     5987 non-null   object
#  17  divulgacao_relatorio_publicado  6769 non-null   object
#  18  divulgacao_dia_publicacao       1781 non-null   object
#  19  total_recomendacoes             6769 non-null   int64
#  20  total_aeronaves_envolvidas      6769 non-null   int64
#  21  ocorrencia_saida_pista          6769 non-null   object
# dtypes: datetime64[ns](1), int64(7), object(14)
# memory usage: 1.1+ MB

# %%
#Verifica se dados são unicos na coluna
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
#Setar novo rótulo do DF
df.set_index('codigo_ocorrencia',inplace=True)

# %%
#resetar o Rotulo(index) do DF
df.reset_index(inplace=True)

# %% [markdown]
# ##Tranformações (Limpeza, conversão , etc)

# %%
#Backup local(M.RAM) do df
dfback = df.copy()

# %%
# Drop de colunas identicas ( codigo_ocorrencia1 , codigo_ocorrencia2,codigo_ocorrencia3 , codigo_ocorrencia4)
df.drop(['codigo_ocorrencia1','codigo_ocorrencia2','codigo_ocorrencia3','codigo_ocorrencia4'],axis=1,inplace=True)
# Drop de colunas com problemas e/ou não utilizadas na analise
df.drop(['ocorrencia_latitude','ocorrencia_longitude','investigacao_aeronave_liberada','investigacao_status','divulgacao_relatorio_numero','divulgacao_relatorio_publicado','divulgacao_dia_publicacao'],axis=1,inplace=True)

# %%
df.drop(['data','horario'],axis=1,inplace=True)

# %%
#Renomeando colunas
df.rename(columns={'ocorrencia_classificacao':'classificacao','ocorrencia_cidade':'cidade','ocorrencia_uf':'uf','ocorrencia_pais':'pais'},inplace=True)
df.rename(columns={'ocorrencia_aerodromo':'aerodromo','ocorrencia_dia':'data','ocorrencia_hora':'horario','total_aeronaves_envolvidas':'n_aeronaves','ocorrencia_saida_pista':'saida_pista'},inplace=True)

# %%
#Visualiza valores unicos na coulna
pd.unique(df['aerodromo'])
# Out:
# array(['SBSP', 'SBVT', 'SDAI', 'SBBH', 'SBEG', nan, 'SBNV', 'SBUL',
#        'SBAU', 'SBBP', 'SBTE', 'SBGR', 'SBMT', 'SBCT', 'SBCF', 'SIEK',
#        'SBRJ', 'SDLP', 'SWPD', 'SBMA', 'SNYP', 'SNHH', 'SBJF', 'SBCY',
#        'SBPS', 'SBMK', 'SBNF', 'SBTF', 'SSMK', 'SNAX', 'SBKP', 'SBFZ',
#        'SNPA', 'SBIZ', 'SNFX', 'SDRK', 'SBRF', 'SSBN', 'SBPR', 'SBSJ',
#        'SBST', 'SBGO', 'SDCO', 'SBSV', 'SBPJ', 'SBGL', 'SBRD', 'SBBE',
#        'SBCH', 'SBLO', 'SBPL', 'SWGW', 'SWLB', 'SBBU', 'SBMQ', 'SIPO',
#        'SIAN', 'SBJV', 'SNDC', 'SBBI', 'SBSC', 'SSKG', 'SBBR', 'SSBG',
#        'SBIL', 'SBPO', 'SDAM', 'SSOG', 'SBPV', 'SBSR', 'SBBV', 'SBSN',
#        'SBFI', 'SDFD', 'SJEH', 'SBSI', 'SWFN', 'SDIG', 'SNHS', 'SBJP',
#        'SBPA', 'SBJA', 'SBJR', 'SBRP', 'SISN', 'SBMO', 'SNRU', 'SNQV',
#        'SNCP', 'SDIH', 'SBTG', 'SIVU', 'SWMV', 'SIRI', 'SNIT', 'SBRB',
#        'SSPI', 'SWCA', 'SBJI', 'SBFL', 'SDRC', 'SNMH', 'SNBS', 'SWLW',
#        'SSOT', 'SNPO', 'SBCG', 'SBJD', 'SDEN', 'APUA', 'SDAG', 'SIUD',
#        'SDBB', 'SBMS', 'SDDR', 'SDVH', 'SSKK', 'SJVX', 'SBVH', 'SDRV',
#        'SBML', 'SSGP', 'SD6Y', 'SNJL', 'SDZS', 'SIBK', 'SNDV', 'SBJH',
#        'SBCZ', 'SSNH', 'SBMG', 'SSZR', 'SDAE', 'SSOL', 'SIFQ', 'SSWF',
#        'SBPP', 'SBAX', 'SJLJ', 'SDPW', 'SSFB', 'SBSG', 'SDTB', 'SSCE',
#        'SSBL', 'SNCT', 'SILQ', 'SSQZ', 'SILT', 'SBIH', 'SIFW', 'SBDN',
#        'SWHP', 'SNGW', 'SBPG', 'SJOG', 'SJPT', 'SWPI', 'SWNG', 'SSKT',
#        'SJNC', 'SBEK', 'SWON', 'SIZM', 'SWME', 'SJOD', 'SBCB', 'SDVG',
#        'SSPO', 'SBCR', 'SBCX', 'SSCD', 'SIXE', 'SNLM', 'SDIP', 'SBTV',
#        'SWNH', 'SSCL', 'SJBX', 'SNGA', 'SIMQ', 'SIQE', 'SWXV', 'SWXQ',
#        '9PBS', 'SISY', 'SDLL', 'SNCJ', 'SBGP', 'SDUL', 'SIVB', 'SWNS',
#        'SDRS', 'SSNG', 'SBZM', 'SSRA', 'SWLC', 'SWTS', 'SWEN', 'SBNM',
#        'SBAT', 'SBMD', 'SJIJ', 'SBSL', 'SDAA', 'SBCP', 'SWRW', 'SWVW',
#        'SJYG', 'SBVG', 'SJGL', 'SSFE', 'SSIE', 'SJLY', 'SWEK', 'SSCK',
#        'SBGV', 'SNDT', 'SIMB', 'SNRP', 'SSXO', 'SSUL', '9PAA', 'SDCD',
#        'SNAS', 'SWEJ', 'SIFC', 'SSDK', 'SBJC', 'SBTT', 'SSKZ', 'SBCA',
#        'SWPY', 'SSOK', 'SDYJ', 'SWFR', '9PSD', 'SNAL', 'SDOI', 'SBGW',
#        'SDJA', 'SSSC', 'SWGI', 'SNPC', 'SDEM', 'SJIF', 'SSGG', 'SIVQ',
#        'SBIT', 'SDLY', 'SJVL', 'SDET', 'SBUY', 'SDJO', 'SNLF', 'SDIO',
#        'SDVO', 'SNIZ', 'SDVK', 'SIBO', 'SWFX', 'SSVA', 'SWMZ', 'SSER',
#        'SNEJ', 'SNQX', 'SDGR', 'SILC', 'SWUZ', 'SDSC', 'SBTA', 'SWEW',
#        'SBJU', 'SSGA', 'SDUB', 'SSCN', 'SSUB', 'SNWC', 'SWYV', 'SBLJ',
#        'SJBH', 'SBFS', 'SNJK', 'SNME', 'SWVC', 'SJNP', 'SNOF', 'SWFV',
#        'SDQG', 'SJBY', 'SNCV', 'SNBR', 'SJQN', 'SSRS', 'SWJP', 'SNMA',
#        'SSMW', 'SIJY', 'SNJR', 'SNGX', 'SNMD', 'SNDU', 'SDDN', 'SNJI',
#        'SDTK', 'SSMH', '9PHD', 'SDPA', 'SNGS', 'SBUR', 'SBPF', 'SIPB',
#        'SBLE', 'SNSH', 'SNDH', 'SWSI', 'SNPY', 'SSOS', 'SWEF', 'SJBM',
#        'SSGB', 'SDGX', 'SIXD', 'SNGQ', 'SWUV', 'SBAE', 'SBTR', 'SSZL',
#        'SJWQ', 'SNBA', 'SBPB', 'SNDP', 'SWPM', 'SDOW', 'SSNV', 'SWVI',
#        'SSGX', 'SNKH', 'SWVR', 'SDTF', 'SSKW', 'SWVZ', 'SNJO', 'SNTO',
#        'SJXM', 'SDNH', '5JTI', 'SNFS', 'SSFC', 'SWGN', 'SIBH', 'SJFM',
#        'SBQV', 'SDTO', 'SDKH', 'SDXF', 'SWGC', 'SWSL', 'SBAQ', 'SWLV',
#        'SNMU', 'SNPD', 'SWKT', 'SDEE', 'SWGL', 'SDNB', 'SWNK', 'SDNI',
#        'SSKM', 'SSJL', 'SJLU', 'SBCJ', 'SDIM', 'SJAH', 'SNNL', 'SWIN',
#        '9PFX', 'SSBR', 'SBPC', 'SNZA', 'SJVO', 'SDLZ', 'SBSM', 'SSSE',
#        'SBHT', 'SIQH', 'SSLT', 'SWPQ', '9PFC', 'SWRZ', 'SNCX', 'SJNQ',
#        'SSSZ', 'SBME', 'SBAR', 'SDMJ', 'SNLO', 'SDVI', 'SNYR', 'SSPB',
#        'SSJA', 'SWJW', 'SING', 'SIQK', 'SD4V', 'SIFV', 'SBBQ', 'SSAK',
#        'SSQI', 'SNJN', 'SDPG', 'SDZX', 'SNPX', 'SNVS', 'SWIT', 'SNYS',
#        'SJLO', 'SWAQ', 'SDYF', 'SDBN', 'SBFE', 'SWQI', 'SIKC', 'SNSG',
#        'SDWU', 'SWPA', 'SSPV', 'SJDU', 'SWRD', 'SSSS', 'SWMO', 'SDJL',
#        'SDMH', 'SWRO', 'SDWC', 'SSJI', 'SNJD', 'SNOG', 'SNHB', 'SBPK',
#        'SWKO', 'SNKF', 'SIPY', 'SNVC', 'SDMM', 'SDVE', 'SWBE', 'SWMW',
#        'SDEH', 'SNXW', 'SJYR', 'SNCW', 'SSAU', 'SDJC', 'SBTD', 'SNHE',
#        'SBUA', 'SSAC', 'SNMX', 'SSCP', 'SSPX', 'SNBO', 'SDWV', 'SWEI',
#        'SBKG', 'SNFE', 'SDED', 'SDRE', 'SWUQ', 'SWBB', 'SIJG', 'SNAU',
#        'SSIJ', 'SBAN', 'SNTY', 'SNKK', 'SNPJ', 'SJRG', 'SBIP', 'SIFH',
#        'SDBK', 'SNVB', 'SSPQ', 'SDBA', 'SNUN', 'SSKS', 'SNXR', 'SNGG',
#        'SSIQ', 'SSPG', 'SNBG', 'SDTI', 'SWJN', 'SDYW', 'SBBW', 'SSPL',
#        'SDHP', 'SSCT', 'SBFN', 'SSDO', 'SSAY', 'SSAQ', 'SDJB', 'SDMC',
#        'SJCY', 'SJFU', 'SNKI', 'SSQT', 'SWOB', 'SDPY', 'SBMY', 'SDVL',
#        'SDPN', 'SSTL', 'SWGP', 'SION', 'SDHU', 'SWNB', 'SNXI', 'SSRZ',
#        'SDDQ', 'SSDP', 'SIPU', 'SNAG', 'SWCZ', 'SNEM', 'SDNE', 'SNGU',
#        'SNSW', 'SDMV', 'SNYE', 'SWYH', 'SNGV', 'SNKE', 'SSSB', 'SSHS',
#        'SNKB', 'SWUI', 'SSNB', 'SJHR', 'SNAZ', 'SBNT', 'SSCR', 'SNTF',
#        'SBBZ', 'SNOD', 'SNCL', 'SJTO', 'SDBV', 'SIRS', 'SJHG', 'SNDR',
#        'SIBX', 'SDOR', 'SWNO', 'SNIG', 'SWKC', 'SBTK', 'SSTH', 'SBUF',
#        'SNFJ', 'SDKE', 'SWDC', 'SDLO', 'SNWS', 'SSCF', 'SNXT', 'SSPS',
#        'SSVN', 'SNUZ', 'SBPN', 'SWOZ', 'SSUV', 'SNVR'], dtype=object)

# %% [markdown]
# Inconsistencias encontradas
# colunas aerodromo , uf
#
# ```
# ('***', '**NI')
# ```

# %%
df.replace(['***','**NI'],pd.NA,inplace=True)

# %%
df.replace(pd.NA,np.NaN,inplace=True)

# %%
#Converter coluna data para string
df['data'] = df['data'].astype(str)

# %%
#Criar coluna periodo (data + horario)
df['periodo'] = pd.to_datetime(df['data']+' '+df['horario'])

# %%
#Verificar dados Nulos , ausentes , etc
df.isna().sum()
# Out:
# codigo_ocorrencia         0
# classificacao             0
# cidade                    0
# uf                        4
# pais                      0
# aerodromo              2618
# data                      0
# horario                   2
# total_recomendacoes       0
# n_aeronaves               0
# saida_pista               0
# dtype: int64

# %%
df.count()
# Out:
# codigo_ocorrencia      6769
# classificacao          6769
# cidade                 6769
# uf                     6765
# pais                   6769
# aerodromo              4151
# data                   6769
# horario                6767
# total_recomendacoes    6769
# n_aeronaves            6769
# saida_pista            6769
# dtype: int64

# %% [markdown]
# ##Criação do Schema de validação de dados

# %%
df.dtypes
# Out:
# codigo_ocorrencia               int64
# classificacao                  object
# cidade                         object
# uf                             object
# pais                           object
# aerodromo                      object
# total_recomendacoes             int64
# n_aeronaves                     int64
# saida_pista                    object
# periodo                datetime64[ns]
# dtype: object

# %%
#Criação do schema pandera

schema = pa.DataFrameSchema(
    columns = {
        'codigo_ocorrencia':pa.Column(pa.Int),
        'classificacao':pa.Column(pa.String),
        'cidade':pa.Column(pa.String),
        'uf':pa.Column(pa.String,pa.Check.str_length(2,2),nullable=True),
        'pais':pa.Column(pa.String),
        'aerodromo':pa.Column(pa.String,pa.Check.str_length(4,4),nullable=True),
        'data':pa.Column(pa.DateTime),
        'horario':pa.Column(pa.String,pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$'),nullable=True),
        'total_recomendacoes':pa.Column(pa.Int),
        'n_aeronaves':pa.Column(pa.Int),
        'saida_pista':pa.Column(pa.String,pa.Check.str_length(3,3)),
    }
)

schema2 = pa.DataFrameSchema(
    columns = {
        'codigo_ocorrencia':pa.Column(pa.Int),
        'classificacao':pa.Column(pa.String),
        'cidade':pa.Column(pa.String),
        'uf':pa.Column(pa.String,pa.Check.str_length(2,2),nullable=True),
        'pais':pa.Column(pa.String),
        'aerodromo':pa.Column(pa.String,pa.Check.str_length(4,4),nullable=True),
        'total_recomendacoes':pa.Column(pa.Int),
        'n_aeronaves':pa.Column(pa.Int),
        'saida_pista':pa.Column(pa.String,pa.Check.str_length(3,3)),
        'periodo':pa.Column(pa.DateTime,nullable=True),
    }
)

# %%
df.loc[0,'aerodromo'] = 'SBSP'

# %%
schema2.validate(df)
# Out:
#       codigo_ocorrencia    classificacao              cidade  uf    pais  \
# 0                 81027  INCIDENTE GRAVE           SÃO PAULO  SP  BRASIL
# 1                 81030        INCIDENTE             VITÓRIA  ES  BRASIL
# 2                 81023  INCIDENTE GRAVE           AMERICANA  SP  BRASIL
# 3                 81029        INCIDENTE      BELO HORIZONTE  MG  BRASIL
# 4                 81025        INCIDENTE              MANAUS  AM  BRASIL
# ...                 ...              ...                 ...  ..     ...
# 6764              40324        INCIDENTE             PELOTAS  RS  BRASIL
# 6765              39527         ACIDENTE  LUCAS DO RIO VERDE  MT  BRASIL
# 6766              40211        INCIDENTE      RIO DE JANEIRO  RJ  BRASIL
# 6767              40349        INCIDENTE               BELÉM  PA  BRASIL
# 6768              40351        INCIDENTE      RIO DE JANEIRO  RJ  BRASIL
#
#      aerodromo  total_recomendacoes  n_aeronaves saida_pista  \
# 0         SBSP                    0            1         SIM
# 1         SBVT                    0            1         NÃO
# 2         SDAI                    0            1         SIM
# 3         SBBH                    0            1         NÃO
# 4         SBEG                    0            1         NÃO
# ...        ...                  ...          ...         ...
# 6764      SBPK                    0            1         NÃO
# 6765       NaN                    0            1         NÃO
# 6766       NaN                    0            1         NÃO
# 6767      SBBE                    0            1         NÃO
# 6768      SBRJ                    0            1         NÃO
#
#                  periodo
# 0    2022-10-09 16:30:00
# 1    2022-10-09 16:20:00
# 2    2022-10-06 15:30:00
# 3    2022-10-06 00:44:00
# 4    2022-10-05 20:56:00
# ...                  ...
# 6764 2010-01-05 19:25:00
# 6765 2010-01-04 17:30:00
# 6766 2010-01-03 12:00:00
# 6767 2010-01-03 11:05:00
# 6768 2010-01-03 03:00:00
#
# [6769 rows x 10 columns]

# %% [markdown]
# ##Busca(query)

# %%
#alterar um valor 
df.loc[0,'aerodromo'] = 'SBSP'

# %%
#busca avançada
df.loc[[0,1000,2000],['classificacao','uf']]
# Out:
#         classificacao  uf
# 0     INCIDENTE GRAVE  SP
# 1000  INCIDENTE GRAVE  RR
# 2000        INCIDENTE  PB

# %%
df.loc[df.classificacao == 'INCIDENTE GRAVE',['classificacao']] = 'YURI'

# %%
df.loc[df.classificacao == 'YURI',['classificacao']] = 'INCIDENTE GRAVE'

# %%
df['backaero'] = df.aerodromo

# %%
df.loc[0,'n_aeronaves'] = '1'

# %%
#conversão do tipo das colunas
df['n_aeronaves'] = df['n_aeronaves'].astype('int')

# %% [markdown]
# ##Filtros

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia         0
# classificacao             0
# cidade                    0
# uf                        4
# pais                      0
# aerodromo              2618
# data                      0
# horario                   2
# total_recomendacoes       0
# n_aeronaves               0
# saida_pista               0
# backaero               2618
# dtype: int64

# %%
filtronulo = df.uf.isna()
df.loc[filtronulo]
# Out:
#       codigo_ocorrencia classificacao                cidade   uf    pais  \
# 283               80665      ACIDENTE      NÃO IDENTIFICADA  NaN  BRASIL
# 320               80631     INCIDENTE      NÃO IDENTIFICADA  NaN  BRASIL
# 912               79956      ACIDENTE      NÃO IDENTIFICADA  NaN  BRASIL
# 4541              49474      ACIDENTE  ÁGUAS INTERNACIONAIS  NaN  BRASIL
#
#      aerodromo       data   horario  total_recomendacoes  n_aeronaves  \
# 283        NaN 2022-04-22  20:00:00                    0            1
# 320        NaN 2022-04-04  11:15:00                    0            1
# 912        NaN 2021-02-26  11:00:00                    0            1
# 4541       NaN 2013-09-02  02:54:00                    0            1
#
#      saida_pista backaero
# 283          NÃO      NaN
# 320          NÃO      NaN
# 912          NÃO      NaN
# 4541         NÃO      NaN

# %%
filtroincidente = df.classificacao =='INCIDENTE'
#dfacidente = df.loc[filtroacidente]

# %%
#filtro com mais detalhes
ftcidade = df.cidade == 'SÃO PAULO'
ftpista = df.saida_pista  == 'SIM'
ft2021 = df.data.dt.year == 2021
ftuf = df.uf == 'SP'

# %%
dfsp = df.loc[ftpista & ft2021 & ftuf]

# %%
ftabril = df.data.dt.month == 4
ftquinz = (df.data.dt.day > 0) & (df.data.dt.day <16)
df.loc[ftabril & ftquinz]
# Out:
#       codigo_ocorrencia    classificacao         cidade  uf    pais aerodromo  \
# 296               80648  INCIDENTE GRAVE      IBOTIRAMA  BA  BRASIL      SNIT
# 297               80658        INCIDENTE      SÃO PAULO  SP  BRASIL      SBGR
# 298               80678        INCIDENTE         RECIFE  PE  BRASIL      SBRF
# 299               80647  INCIDENTE GRAVE     RIO BRANCO  AC  BRASIL      SBRB
# 300               80653         ACIDENTE       MINEIROS  GO  BRASIL       NaN
# ...                 ...              ...            ...  ..     ...       ...
# 6650              40251        INCIDENTE  FLORIANÓPOLIS  SC  BRASIL       NaN
# 6651              40267  INCIDENTE GRAVE      VERA CRUZ  BA  BRASIL      SNVR
# 6652              40291        INCIDENTE        CONFINS  MG  BRASIL      SBCF
# 6653              40275        INCIDENTE       BRASÍLIA  DF  BRASIL      SBBR
# 6654              40288        INCIDENTE      FORTALEZA  CE  BRASIL      SBFZ
#
#            data   horario  total_recomendacoes  n_aeronaves saida_pista  \
# 296  2022-04-15  14:25:00                    0            1         SIM
# 297  2022-04-15  11:00:00                    0            1         NÃO
# 298  2022-04-15  00:00:00                    0            1         NÃO
# 299  2022-04-14  17:45:00                    0            1         NÃO
# 300  2022-04-14  10:30:00                    0            1         NÃO
# ...         ...       ...                  ...          ...         ...
# 6650 2010-04-04  17:00:00                    0            1         NÃO
# 6651 2010-04-04  11:00:00                    2            1         NÃO
# 6652 2010-04-03  20:25:00                    0            1         NÃO
# 6653 2010-04-02  18:15:00                    0            1         NÃO
# 6654 2010-04-01  13:16:00                    0            1         NÃO
#
#      backaero
# 296      SNIT
# 297      SBGR
# 298      SBRF
# 299      SBRB
# 300       NaN
# ...       ...
# 6650      NaN
# 6651     SNVR
# 6652     SBCF
# 6653     SBBR
# 6654     SBFZ
#
# [301 rows x 12 columns]

# %%
# Filtro para palavras terminadas em RIO
filtroletras = df.cidade.str[-3:] == 'RIO'
df.loc[filtroletras]
# Out:
#       codigo_ocorrencia    classificacao                 cidade  uf    pais  \
# 649               80256        INCIDENTE              CABO FRIO  RJ  BRASIL
# 936               79894         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 940               79889         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 952               79881  INCIDENTE GRAVE              CABO FRIO  RJ  BRASIL
# 1211              79497         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 1278              79407         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 1499              79100  INCIDENTE GRAVE                LADÁRIO  MS  BRASIL
# 1866              78799  INCIDENTE GRAVE              CABO FRIO  RJ  BRASIL
# 1940              78550         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 2178              78102  INCIDENTE GRAVE                 OSÓRIO  RS  BRASIL
# 2299              77868         ACIDENTE      QUARTO CENTENÁRIO  PR  BRASIL
# 2344              77785         ACIDENTE                ROSÁRIO  MA  BRASIL
# 2345              77790        INCIDENTE                ROSÁRIO  MA  BRASIL
# 2386              77733         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 2391              77710         ACIDENTE                 OSÓRIO  RS  BRASIL
# 2408              77660         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 2471              77211        INCIDENTE              CABO FRIO  RJ  BRASIL
# 2503              77299         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 2658              67022        INCIDENTE              CABO FRIO  RJ  BRASIL
# 2771              66650         ACIDENTE              CABO FRIO  RJ  BRASIL
# 2821              66489         ACIDENTE           PEDRO OSÓRIO  RS  BRASIL
# 2835              66549         ACIDENTE           PEDRO OSÓRIO  RS  BRASIL
# 2857              66362         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 3057              65546  INCIDENTE GRAVE                NAZÁRIO  GO  BRASIL
# 3276              60661         ACIDENTE                 OSÓRIO  RS  BRASIL
# 3438              53594        INCIDENTE              CABO FRIO  RJ  BRASIL
# 3612              53229        INCIDENTE              CABO FRIO  RJ  BRASIL
# 3661              53165  INCIDENTE GRAVE          SÃO DESIDÉRIO  BA  BRASIL
# 3723              52974         ACIDENTE    PRESIDENTE OLEGÁRIO  MG  BRASIL
# 3794              52835         ACIDENTE                NAZÁRIO  GO  BRASIL
# 3903              52553  INCIDENTE GRAVE  SENADOR JOSÉ PORFÍRIO  PA  BRASIL
# 4131              51004         ACIDENTE          SÃO DESIDÉRIO  BA  BRASIL
# 4160              51330        INCIDENTE              CABO FRIO  RJ  BRASIL
# 4233              51019  INCIDENTE GRAVE              CABO FRIO  RJ  BRASIL
# 4305              51073        INCIDENTE              CABO FRIO  RJ  BRASIL
# 4320              52940         ACIDENTE      QUARTO CENTENÁRIO  PR  BRASIL
# 4925              47063        INCIDENTE              CABO FRIO  RJ  BRASIL
# 5125              46698        INCIDENTE              CABO FRIO  RJ  BRASIL
# 5264              52063        INCIDENTE              CABO FRIO  RJ  BRASIL
# 5324              46196        INCIDENTE                 OSÓRIO  RS  BRASIL
# 5345              46197        INCIDENTE                 OSÓRIO  RS  BRASIL
# 5377              45946        INCIDENTE              CABO FRIO  RJ  BRASIL
# 5509              45685        INCIDENTE              CABO FRIO  RJ  BRASIL
# 5566              45712        INCIDENTE              CABO FRIO  RJ  BRASIL
# 5809              51778        INCIDENTE              CABO FRIO  RJ  BRASIL
# 5886              44906        INCIDENTE              CABO FRIO  RJ  BRASIL
# 5917              44698        INCIDENTE              CABO FRIO  RJ  BRASIL
# 6735              39318         ACIDENTE  SENADOR JOSÉ PORFÍRIO  PA  BRASIL
#
#      aerodromo       data   horario  total_recomendacoes  n_aeronaves  \
# 649       SBCB 2021-08-21  15:10:00                    0            1
# 936        NaN 2021-02-16  11:30:00                    0            1
# 940        NaN 2021-02-12  13:00:00                    0            1
# 952       SBCB 2021-02-05  21:00:00                    0            1
# 1211       NaN 2020-08-20  18:20:00                    2            1
# 1278       NaN 2020-06-20  16:30:00                    0            1
# 1499      SSVA 2020-01-16  16:15:00                    0            1
# 1866       NaN 2019-04-18  21:09:00                    2            2
# 1940      APUA 2019-02-23  11:05:00                    1            1
# 2178      SSOS 2018-08-04  19:15:00                    0            2
# 2299       NaN 2018-05-06  18:00:00                    1            1
# 2344       NaN 2018-04-01  19:00:00                    0            1
# 2345       NaN 2018-04-01  20:50:00                    0            1
# 2386       NaN 2018-03-07  17:10:00                    3            1
# 2391       NaN 2018-03-04  14:43:00                    0            1
# 2408       NaN 2018-02-18  19:15:00                    2            1
# 2471      SBCB 2017-12-23  13:15:00                    0            1
# 2503       NaN 2017-11-26  12:30:00                    0            1
# 2658       NaN 2017-07-17  18:00:00                    0            1
# 2771      9PFX 2017-04-15  19:40:00                    0            1
# 2821       NaN 2017-03-06  15:05:00                    1            1
# 2835       NaN 2017-02-22  12:30:00                    0            1
# 2857       NaN 2017-02-04  13:30:00                    0            1
# 3057       NaN 2016-08-10  20:20:00                    0            1
# 3276      SSOS 2016-01-20  12:00:00                    4            1
# 3438      SBCB 2015-09-14  13:00:00                    0            1
# 3612      SBCB 2015-04-20  10:20:00                    0            1
# 3661       NaN 2015-03-20  14:35:00                    0            1
# 3723       NaN 2015-02-02  19:50:00                    0            1
# 3794       NaN 2014-12-17  12:10:00                    0            1
# 3903      SDWV 2014-09-23  20:30:00                    0            1
# 4131       NaN 2014-04-22  19:45:00                    2            1
# 4160       NaN 2014-04-07  17:15:00                    0            1
# 4233      SBCB 2014-02-16  09:52:00                    0            1
# 4305      SBCB 2014-01-17  10:17:00                    0            1
# 4320       NaN 2014-01-11  10:40:00                    0            1
# 4925      SBCB 2013-02-06  17:25:00                    0            1
# 5125      SBCB 2012-10-26  15:42:00                    0            1
# 5264      SBCB 2012-08-15  15:00:00                    0            1
# 5324      SSOS 2012-07-09  12:00:00                    0            1
# 5345      SSOS 2012-06-26  17:00:00                    0            1
# 5377      SBCB 2012-06-11  14:50:00                    0            1
# 5509      SBBZ 2012-03-18  12:20:00                    0            1
# 5566       NaN 2012-02-17  12:00:00                    0            1
# 5809      SBCB 2011-09-01  13:10:00                    0            1
# 5886       NaN 2011-07-15  16:48:00                    0            1
# 5917       NaN 2011-06-28  11:58:00                    0            1
# 6735       NaN 2010-01-25  16:20:00                    5            1
#
#      saida_pista backaero
# 649          NÃO     SBCB
# 936          NÃO      NaN
# 940          SIM      NaN
# 952          NÃO     SBCB
# 1211         NÃO      NaN
# 1278         NÃO      NaN
# 1499         NÃO     SSVA
# 1866         NÃO      NaN
# 1940         NÃO     APUA
# 2178         NÃO     SSOS
# 2299         NÃO      NaN
# 2344         NÃO      NaN
# 2345         NÃO      NaN
# 2386         NÃO      NaN
# 2391         NÃO      NaN
# 2408         NÃO      NaN
# 2471         NÃO     SBCB
# 2503         NÃO      NaN
# 2658         NÃO      NaN
# 2771         NÃO     9PFX
# 2821         NÃO      NaN
# 2835         NÃO      NaN
# 2857         NÃO      NaN
# 3057         SIM      NaN
# 3276         NÃO     SSOS
# 3438         NÃO     SBCB
# 3612         NÃO     SBCB
# 3661         NÃO      NaN
# 3723         NÃO      NaN
# 3794         NÃO      NaN
# 3903         SIM     SDWV
# 4131         NÃO      NaN
# 4160         NÃO      NaN
# 4233         NÃO     SBCB
# 4305         NÃO     SBCB
# 4320         NÃO      NaN
# 4925         NÃO     SBCB
# 5125         NÃO     SBCB
# 5264         NÃO     SBCB
# 5324         NÃO     SSOS
# 5345         NÃO     SSOS
# 5377         NÃO     SBCB
# 5509         NÃO     SBBZ
# 5566         NÃO      NaN
# 5809         NÃO     SBCB
# 5886         NÃO      NaN
# 5917         NÃO      NaN
# 6735         NÃO      NaN

# %%
#Filtro para letras dentro do valor
filtrointerno = df.cidade.str.contains('MA')

# %%
df.loc[filtrointerno]
# Out:
#       codigo_ocorrencia    classificacao              cidade  uf    pais  \
# 4                 81025        INCIDENTE              MANAUS  AM  BRASIL
# 34                80969        INCIDENTE              MARABÁ  PA  BRASIL
# 56                80938        INCIDENTE              MARABÁ  PA  BRASIL
# 72                80947        INCIDENTE              MANAUS  AM  BRASIL
# 92                80964        INCIDENTE              PALMAS  TO  BRASIL
# ...                 ...              ...                 ...  ..     ...
# 6690              39916  INCIDENTE GRAVE              MANAUS  AM  BRASIL
# 6733              39487  INCIDENTE GRAVE              PALMAS  TO  BRASIL
# 6750              39315         ACIDENTE            CANUTAMA  AM  BRASIL
# 6755              39507         ACIDENTE  PRIMAVERA DO LESTE  MT  BRASIL
# 6761              39707  INCIDENTE GRAVE            CANUTAMA  AM  BRASIL
#
#      aerodromo       data   horario  total_recomendacoes  n_aeronaves  \
# 4         SBEG 2022-10-05  20:56:00                    0            1
# 34        SBMA 2022-09-10  17:45:00                    0            1
# 56        SBMA 2022-08-29       NaN                    0            1
# 72        SBEG 2022-08-20  08:13:00                    0            1
# 92        SBPJ 2022-08-11  05:31:00                    0            1
# ...        ...        ...       ...                  ...          ...
# 6690      SBEG 2010-03-07  19:35:00                    2            1
# 6733      SBPJ 2010-01-26  16:50:00                    0            1
# 6750       NaN 2010-01-15  21:22:00                    0            1
# 6755       NaN 2010-01-11  17:00:00                    2            1
# 6761       NaN 2010-01-09  12:30:00                    3            1
#
#      saida_pista backaero
# 4            NÃO     SBEG
# 34           NÃO     SBMA
# 56           NÃO     SBMA
# 72           NÃO     SBEG
# 92           NÃO     SBPJ
# ...          ...      ...
# 6690         SIM     SBEG
# 6733         NÃO     SBPJ
# 6750         NÃO      NaN
# 6755         NÃO      NaN
# 6761         NÃO      NaN
#
# [569 rows x 12 columns]

# %% [markdown]
# ##GroupBY ( Agrupamentos)

# %%
df.groupby(['classificacao']).size().sort_values(ascending=False)
# Out:
# classificacao
# INCIDENTE          3795
# ACIDENTE           2090
# INCIDENTE GRAVE     884
# dtype: int64

# %%
df.groupby(['aerodromo'],dropna=False).size().sort_values(ascending=False)
# Out:
# aerodromo
# NaN     2618
# SBGR     173
# SBMT     150
# SBKP     128
# SBBH     124
#         ...
# SJVL       1
# SJTO       1
# SJOD       1
# SJNQ       1
# SJNC       1
# Length: 574, dtype: int64

# %%
dfacidente.groupby(['aerodromo'],dropna=False).size().sort_values(ascending=False)
# Out:
# aerodromo
# NaN     1363
# APUA      17
# SBMT      16
# SBNV      12
# SBBP      12
#         ...
# SIXD       1
# SIZM       1
# SJBH       1
# SJBY       1
# SJLY       1
# Length: 370, dtype: int64

# %%
#filtro sul e incidentes
filtrosul = df.uf.isin(['RS','PR','SC'])
dfsul = df.loc[filtroincidente & filtrosul]

# %%
dfsul.groupby(['uf']).size().sort_values(ascending=False)
# Out:
# uf
# PR    316
# RS    157
# SC    132
# dtype: int64

# %%
dfsp.groupby(['classificacao']).size().sort_values(ascending=False)
# Out:
# classificacao
# ACIDENTE           7
# INCIDENTE          3
# INCIDENTE GRAVE    3
# dtype: int64

# %% [markdown]
# ##Plotagem

# %%
df.groupby(['uf'],dropna=False).size().sort_values(ascending=False).plot.bar(figsize=(12,8),xlabel='ESTADO',ylabel='N. Ocorrencias')
# Out:
# <AxesSubplot:xlabel='ESTADO', ylabel='N. Ocorrencias'>

# %%
df.groupby('saida_pista',dropna=False).size().sort_values(ascending=False).plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# ##LOAD (Carregamento) salvar o df.

# %%
#Utilizar se for o rotulo padrão 
df.to_csv('cenipa_tratado_ok.csv',index=False)

# %%
#Carregar direto no bucket
df.to_csv('gs://projeto_pandas/brutos/teste.csv',index=False)

# %% [markdown]
# ##ALESP

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://storage.googleapis.com/projeto_pandas/depsp.csv')

# %%
df_despesas = df

# %%
df.head()
# Out:
#     Ano  Matricula  Mes    Valor            CNPJ            Deputado  \
# 0  2015     300257    3   200.00  71806251000106  ABELARDO CAMARINHA
# 1  2015     300257    3   295.40  68064740000125  ABELARDO CAMARINHA
# 2  2015     300257    3  2850.00     22145388877  ABELARDO CAMARINHA
# 3  2015     300257    4   100.00  10915883000113  ABELARDO CAMARINHA
# 4  2015     300257    4   195.01  71806251000106  ABELARDO CAMARINHA
#
#                                                 Tipo  \
# 0                   A - COMBUSTÍVEIS E LUBRIFICANTES
# 1  E - MATERIAIS DE ESCRITÓRIO E OUTROS MATERIAIS...
# 2                                        N - MORADIA
# 3                   A - COMBUSTÍVEIS E LUBRIFICANTES
# 4                   A - COMBUSTÍVEIS E LUBRIFICANTES
#
#                          Fornecedor
# 0  AUTO POSTO DE SERVIÇOS MARV LTDA
# 1         PAPER FACE COMERCIAL LTDA
# 2         LARA SERVINO VARGAS ABREU
# 3     CENTRO AUTOMOTIVO TOP 23 LTDA
# 4  AUTO POSTO DE SERVIÇOS MARV LTDA

# %%
# CNPJ:
print(len(df_despesas.CNPJ.unique()))
df_despesas_cnpj = pd.DataFrame(df_despesas.CNPJ.unique(), columns=["CNPJ"])
# Out:
# 60531

# %%
# Investigando mais profundamente a coluna CNPJ:
valores_estranhos = []
for i in range(len(df_despesas_cnpj)):
  try:
    int(df_despesas_cnpj.loc[i, "CNPJ"])
  except Exception:
    valores_estranhos.append(df_despesas_cnpj.loc[i, "CNPJ"])
print("Para corrigir: ")
print(valores_estranhos)
# Out:
# Para corrigir:
# [nan, 'O4689799000126', 'O4040553000129', 'O2358317000120', 'O1520430000105', '00O21449000136', 'O7482309000104']

# %%
filtro = df_despesas.CNPJ =='O4689799000126'
df_despesas.loc[56568,'CNPJ']
# Out:
# 4689799000126.0

# %%
df_despesas.loc[56568]
# Out:
# Ano                                                        2007
# Matricula                                                300482
# Mes                                                          11
# Valor                                                     76.78
# CNPJ                                            4689799000126.0
# Deputado                                         ANTÔNIO CARLOS
# Tipo          I - HOSPEDAGEM, ALIMENTAÇÃO E DESPESAS DE LOCO...
# Fornecedor                                  VIA BARBARESCO LTDA
# Name: 56568, dtype: object

# %%
df_despesas.fillna(np.NaN,inplace=True)

df_despesas.CNPJ.replace(to_replace ="O",value = '0', regex=True,inplace=True)

# %%
df_despesas.CNPJ.fillna(0,inplace=True)

# %%
df_despesas.CNPJ.replace(0,np.NaN,inplace=True)

# %%
df['CNPJ']  = df['CNPJ'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-34-15c8eaf85190> in <module>
# ----> 1 df['CNPJ']  = df['CNPJ'].astype(int)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1211     """
#    1212     if not np.isfinite(values).all():
# -> 1213         raise IntCastingNaNError(
#    1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
filtro = df_despesas.CNPJ.isna()

# %%
df_despesas.head()
# Out:
#     Ano  Matricula  Mes    Valor          CNPJ            Deputado  \
# 0  2015     300257    3   200.00  7.180625e+13  ABELARDO CAMARINHA
# 1  2015     300257    3   295.40  6.806474e+13  ABELARDO CAMARINHA
# 2  2015     300257    3  2850.00  2.214539e+10  ABELARDO CAMARINHA
# 3  2015     300257    4   100.00  1.091588e+13  ABELARDO CAMARINHA
# 4  2015     300257    4   195.01  7.180625e+13  ABELARDO CAMARINHA
#
#                                                 Tipo  \
# 0                   A - COMBUSTÍVEIS E LUBRIFICANTES
# 1  E - MATERIAIS DE ESCRITÓRIO E OUTROS MATERIAIS...
# 2                                        N - MORADIA
# 3                   A - COMBUSTÍVEIS E LUBRIFICANTES
# 4                   A - COMBUSTÍVEIS E LUBRIFICANTES
#
#                          Fornecedor
# 0  AUTO POSTO DE SERVIÇOS MARV LTDA
# 1         PAPER FACE COMERCIAL LTDA
# 2         LARA SERVINO VARGAS ABREU
# 3     CENTRO AUTOMOTIVO TOP 23 LTDA
# 4  AUTO POSTO DE SERVIÇOS MARV LTDA

# %%
df_despesas.dtypes
# Out:
# Ano             int64
# Matricula       int64
# Mes             int64
# Valor         float64
# CNPJ          float64
# Deputado       object
# Tipo           object
# Fornecedor     object
# dtype: object
